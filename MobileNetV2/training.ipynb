# %%
# Transfer learning menggunakan MobileNetV2 Large
from tensorflow.keras import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Path dataset
trainPath = "D:/dataset_daun/train"
validPath = "D:/dataset_daun/val"

# Data augmentation dan preprocessing
trainGenerator = ImageDataGenerator(
    preprocessing_function=preprocess_input,   # <--- Sesuai standar MobileNetV2
    rotation_range=30,                         # ditingkatkan
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=(0.5, 1.5),
    fill_mode='nearest'
).flow_from_directory(trainPath, target_size=(320, 320), batch_size=32, class_mode='categorical')

validGenerator = ImageDataGenerator(
    preprocessing_function=preprocess_input
).flow_from_directory(validPath, target_size=(320, 320), batch_size=32, class_mode='categorical', shuffle=False)
# Out:
# Found 478 images belonging to 26 classes.
# Found 131 images belonging to 26 classes.

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Jumlah kelas sesuai folder train
num_classes = 26  # Ubah ke 29 jika memang hanya 29 kelas

# Layer input eksplisit
input_tensor = Input(shape=(320, 320, 3))

# Base model dari MobileNetV3
baseModel = MobileNetV2(weights='imagenet', include_top=False, input_tensor=input_tensor)

# Head model
x = baseModel.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)

x = Dense(256, activation='relu', kernel_regularizer=l2(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)

x = Dense(128, activation='relu', kernel_regularizer=l2(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)

predictions = Dense(num_classes, activation='softmax')(x)

# Model final
model = Model(inputs=input_tensor, outputs=predictions)

# Freeze sebagian besar layer
for layer in baseModel.layers:
    layer.trainable = False  # Fine-tune nanti di tahap 2 training

# Compile model
optimizer = Adam(learning_rate=1e-4)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# Summary
model.summary()

# plot_model(model, show_shapes=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3288\2390713721.py:15: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   baseModel = MobileNetV2(weights='imagenet', include_top=False, input_tensor=input_tensor)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 160, 160,  │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 160, 160,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 160, 160,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 160, 160,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 160, 160,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 160, 160,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 160, 160,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 160, 160,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 160, 160,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 160, 160,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 160, 160,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 161, 161,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 80, 80,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 80, 80,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 80, 80,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 80, 80,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 80, 80,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 80, 80,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 80, 80,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 80, 80,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 80, 80,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 80, 80,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 80, 80,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 80, 80,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 80, 80,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 80, 80,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 80, 80,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 80, 80,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 80, 80,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 81, 81,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 40, 40,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 40, 40,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 40, 40,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 40, 40,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 40, 40,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 40, 40,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 40, 40,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 40, 40,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 40, 40,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 40, 40,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 40, 40,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 40, 40,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 40, 40,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 40, 40,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 40, 40,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 40, 40,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 40, 40,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 40, 40,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 40, 40,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 40, 40,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 40, 40,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 40, 40,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 40, 40,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 40, 40,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 40, 40,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 40, 40,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 41, 41,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 20, 20,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 20, 20,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 20, 20,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 20, 20,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 20, 20,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 20, 20,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 20, 20,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 20, 20,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 20, 20,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 20, 20,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 20, 20,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 20, 20,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 20, 20,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 20, 20,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 20, 20,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 20, 20,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 20, 20,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 20, 20,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 20, 20,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 20, 20,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 20, 20,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 20, 20,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 20, 20,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 20, 20,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 20, 20,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 20, 20,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 20, 20,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 20, 20,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 20, 20,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 20, 20,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 20, 20,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 20, 20,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 20, 20,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 20, 20,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 20, 20,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 20, 20,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 20, 20,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 20, 20,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 20, 20,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 20, 20,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 20, 20,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 20, 20,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 20, 20,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 20, 20,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 20, 20,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 20, 20,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 20, 20,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 20, 20,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 20, 20,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 20, 20,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 20, 20,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 20, 20,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 20, 20,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 20, 20,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 20, 20,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 20, 20,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 20, 20,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 20, 20,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 20, 20,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 20, 20,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 20, 20,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 21, 21,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 10, 10,    │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 10, 10,    │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 10, 10,    │          0 │ block_13_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 10, 10,    │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 10, 10,    │        640 │ block_13_project… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 10, 10,    │    153,600 │ block_13_project… │
# │ (Conv2D)            │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 10, 10,    │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 10, 10,    │          0 │ block_14_expand_… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 10, 10,    │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 10, 10,    │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 10, 10,    │          0 │ block_14_depthwi… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 10, 10,    │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 10, 10,    │        640 │ block_14_project… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 10, 10,    │          0 │ block_13_project… │
# │                     │ 160)              │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 10, 10,    │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 10, 10,    │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 10, 10,    │          0 │ block_15_expand_… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 10, 10,    │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 10, 10,    │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 10, 10,    │          0 │ block_15_depthwi… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 10, 10,    │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 10, 10,    │        640 │ block_15_project… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 10, 10,    │          0 │ block_14_add[0][… │
# │                     │ 160)              │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 10, 10,    │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 10, 10,    │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 10, 10,    │          0 │ block_16_expand_… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 10, 10,    │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 10, 10,    │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 10, 10,    │          0 │ block_16_depthwi… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 10, 10,    │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 10, 10,    │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 10, 10,    │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 10, 10,    │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 10, 10,    │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │    327,936 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     32,896 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 26)        │      3,354 │ dropout_8[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,623,706 (10.01 MB)
#  Trainable params: 364,954 (1.39 MB)
#  Non-trainable params: 2,258,752 (8.62 MB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callback untuk menyimpan model terbaik berdasarkan val_accuracy
checkpoint_cb = ModelCheckpoint(
    "best_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1
)

# Callback untuk menghentikan training jika tidak ada peningkatan
earlystop_cb = EarlyStopping(
    monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1
)

# Callback untuk menurunkan learning rate jika val_loss stagnan
lr_reduce_cb = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1
)

# Latih model
history = model.fit(
    trainGenerator,
    validation_data=validGenerator,
    epochs=100,
    callbacks=[checkpoint_cb, lr_reduce_cb]
)
# Out:
# c:\Users\ASUS\Documents\Python\BRIN\MobileNetV3\envi_V3\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0383 - loss: 4.1436
# Epoch 1: val_accuracy improved from -inf to 0.06107, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.0385 - loss: 4.1437 - val_accuracy: 0.0611 - val_loss: 3.3885 - learning_rate: 1.0000e-04
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0399 - loss: 3.9298
# Epoch 2: val_accuracy did not improve from 0.06107
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.0403 - loss: 3.9303 - val_accuracy: 0.0611 - val_loss: 3.3152 - learning_rate: 1.0000e-04
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0369 - loss: 3.8015
# Epoch 3: val_accuracy improved from 0.06107 to 0.09160, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.0387 - loss: 3.7990 - val_accuracy: 0.0916 - val_loss: 3.2437 - learning_rate: 1.0000e-04
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0913 - loss: 3.5744
# Epoch 4: val_accuracy improved from 0.09160 to 0.09924, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.0916 - loss: 3.5734 - val_accuracy: 0.0992 - val_loss: 3.1740 - learning_rate: 1.0000e-04
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1390 - loss: 3.4236
# Epoch 5: val_accuracy improved from 0.09924 to 0.11450, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.1389 - loss: 3.4216 - val_accuracy: 0.1145 - val_loss: 3.1033 - learning_rate: 1.0000e-04
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1294 - loss: 3.3599
# Epoch 6: val_accuracy improved from 0.11450 to 0.15267, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.1298 - loss: 3.3550 - val_accuracy: 0.1527 - val_loss: 3.0302 - learning_rate: 1.0000e-04
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1294 - loss: 3.3083
# Epoch 7: val_accuracy improved from 0.15267 to 0.16794, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.1306 - loss: 3.3016 - val_accuracy: 0.1679 - val_loss: 2.9592 - learning_rate: 1.0000e-04
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1794 - loss: 3.2774
# Epoch 8: val_accuracy improved from 0.16794 to 0.19847, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.1796 - loss: 3.2709 - val_accuracy: 0.1985 - val_loss: 2.8866 - learning_rate: 1.0000e-04
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1883 - loss: 2.9998
# Epoch 9: val_accuracy improved from 0.19847 to 0.21374, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.1891 - loss: 2.9967 - val_accuracy: 0.2137 - val_loss: 2.8067 - learning_rate: 1.0000e-04
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1905 - loss: 2.9452
# Epoch 10: val_accuracy improved from 0.21374 to 0.24427, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.1910 - loss: 2.9431 - val_accuracy: 0.2443 - val_loss: 2.7309 - learning_rate: 1.0000e-04
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2713 - loss: 2.6930
# Epoch 11: val_accuracy improved from 0.24427 to 0.25954, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.2703 - loss: 2.6947 - val_accuracy: 0.2595 - val_loss: 2.6412 - learning_rate: 1.0000e-04
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2429 - loss: 2.7925
# Epoch 12: val_accuracy improved from 0.25954 to 0.27481, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.2428 - loss: 2.7899 - val_accuracy: 0.2748 - val_loss: 2.5681 - learning_rate: 1.0000e-04
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2359 - loss: 2.7716
# Epoch 13: val_accuracy improved from 0.27481 to 0.30534, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.2348 - loss: 2.7701 - val_accuracy: 0.3053 - val_loss: 2.5029 - learning_rate: 1.0000e-04
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3020 - loss: 2.6142
# Epoch 14: val_accuracy improved from 0.30534 to 0.31298, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.3024 - loss: 2.6096 - val_accuracy: 0.3130 - val_loss: 2.4283 - learning_rate: 1.0000e-04
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2873 - loss: 2.4857
# Epoch 15: val_accuracy improved from 0.31298 to 0.32061, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.2885 - loss: 2.4782 - val_accuracy: 0.3206 - val_loss: 2.3706 - learning_rate: 1.0000e-04
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2992 - loss: 2.4320
# Epoch 16: val_accuracy improved from 0.32061 to 0.32824, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.3006 - loss: 2.4294 - val_accuracy: 0.3282 - val_loss: 2.3205 - learning_rate: 1.0000e-04
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2763 - loss: 2.4626
# Epoch 17: val_accuracy improved from 0.32824 to 0.35115, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.2785 - loss: 2.4625 - val_accuracy: 0.3511 - val_loss: 2.2686 - learning_rate: 1.0000e-04
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3433 - loss: 2.3846
# Epoch 18: val_accuracy improved from 0.35115 to 0.35878, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.3425 - loss: 2.3836 - val_accuracy: 0.3588 - val_loss: 2.2306 - learning_rate: 1.0000e-04
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3176 - loss: 2.2946
# Epoch 19: val_accuracy improved from 0.35878 to 0.38168, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.3185 - loss: 2.2919 - val_accuracy: 0.3817 - val_loss: 2.1688 - learning_rate: 1.0000e-04
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3649 - loss: 2.2195
# Epoch 20: val_accuracy did not improve from 0.38168
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.3659 - loss: 2.2165 - val_accuracy: 0.3817 - val_loss: 2.1184 - learning_rate: 1.0000e-04
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 110s/step - accuracy: 0.3716 - loss: 2.1836
# Epoch 21: val_accuracy improved from 0.38168 to 0.40458, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1559s 111s/step - accuracy: 0.3730 - loss: 2.1805 - val_accuracy: 0.4046 - val_loss: 2.0786 - learning_rate: 1.0000e-04
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3704 - loss: 2.0295
# Epoch 22: val_accuracy improved from 0.40458 to 0.41985, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 107s 6s/step - accuracy: 0.3706 - loss: 2.0330 - val_accuracy: 0.4198 - val_loss: 2.0306 - learning_rate: 1.0000e-04
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3852 - loss: 2.0406
# Epoch 23: val_accuracy improved from 0.41985 to 0.45038, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - accuracy: 0.3852 - loss: 2.0438 - val_accuracy: 0.4504 - val_loss: 1.9949 - learning_rate: 1.0000e-04
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3873 - loss: 2.1268
# Epoch 24: val_accuracy improved from 0.45038 to 0.45802, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 84s 6s/step - accuracy: 0.3882 - loss: 2.1240 - val_accuracy: 0.4580 - val_loss: 1.9578 - learning_rate: 1.0000e-04
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4620 - loss: 1.9802
# Epoch 25: val_accuracy improved from 0.45802 to 0.47328, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.4599 - loss: 1.9817 - val_accuracy: 0.4733 - val_loss: 1.9203 - learning_rate: 1.0000e-04
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4496 - loss: 2.0079
# Epoch 26: val_accuracy did not improve from 0.47328
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.4485 - loss: 2.0075 - val_accuracy: 0.4580 - val_loss: 1.8869 - learning_rate: 1.0000e-04
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4798 - loss: 1.8328
# Epoch 27: val_accuracy did not improve from 0.47328
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.4803 - loss: 1.8327 - val_accuracy: 0.4733 - val_loss: 1.8587 - learning_rate: 1.0000e-04
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4772 - loss: 1.8413
# Epoch 28: val_accuracy improved from 0.47328 to 0.48092, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.4763 - loss: 1.8408 - val_accuracy: 0.4809 - val_loss: 1.8283 - learning_rate: 1.0000e-04
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4748 - loss: 1.8253
# Epoch 29: val_accuracy improved from 0.48092 to 0.51908, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.4755 - loss: 1.8261 - val_accuracy: 0.5191 - val_loss: 1.7994 - learning_rate: 1.0000e-04
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4814 - loss: 1.8298
# Epoch 30: val_accuracy did not improve from 0.51908
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.4823 - loss: 1.8283 - val_accuracy: 0.5191 - val_loss: 1.7701 - learning_rate: 1.0000e-04
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4775 - loss: 1.8030
# Epoch 31: val_accuracy improved from 0.51908 to 0.53435, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.4786 - loss: 1.8008 - val_accuracy: 0.5344 - val_loss: 1.7400 - learning_rate: 1.0000e-04
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5031 - loss: 1.7617
# Epoch 32: val_accuracy did not improve from 0.53435
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.5038 - loss: 1.7597 - val_accuracy: 0.5344 - val_loss: 1.7156 - learning_rate: 1.0000e-04
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5203 - loss: 1.7221
# Epoch 33: val_accuracy did not improve from 0.53435
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.5208 - loss: 1.7190 - val_accuracy: 0.5344 - val_loss: 1.6978 - learning_rate: 1.0000e-04
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4892 - loss: 1.7855
# Epoch 34: val_accuracy improved from 0.53435 to 0.54962, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.4911 - loss: 1.7789 - val_accuracy: 0.5496 - val_loss: 1.6697 - learning_rate: 1.0000e-04
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5185 - loss: 1.7197
# Epoch 35: val_accuracy did not improve from 0.54962
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.5183 - loss: 1.7187 - val_accuracy: 0.5496 - val_loss: 1.6648 - learning_rate: 1.0000e-04
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5283 - loss: 1.6569
# Epoch 36: val_accuracy improved from 0.54962 to 0.56489, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5292 - loss: 1.6553 - val_accuracy: 0.5649 - val_loss: 1.6473 - learning_rate: 1.0000e-04
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5428 - loss: 1.6131
# Epoch 37: val_accuracy did not improve from 0.56489
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5426 - loss: 1.6123 - val_accuracy: 0.5649 - val_loss: 1.6308 - learning_rate: 1.0000e-04
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5205 - loss: 1.6118
# Epoch 38: val_accuracy did not improve from 0.56489
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.5215 - loss: 1.6106 - val_accuracy: 0.5496 - val_loss: 1.6097 - learning_rate: 1.0000e-04
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5947 - loss: 1.5466
# Epoch 39: val_accuracy did not improve from 0.56489
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5942 - loss: 1.5469 - val_accuracy: 0.5420 - val_loss: 1.5868 - learning_rate: 1.0000e-04
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5539 - loss: 1.7747
# Epoch 40: val_accuracy improved from 0.56489 to 0.58779, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.5547 - loss: 1.7665 - val_accuracy: 0.5878 - val_loss: 1.5577 - learning_rate: 1.0000e-04
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5669 - loss: 1.5065
# Epoch 41: val_accuracy improved from 0.58779 to 0.59542, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5669 - loss: 1.5078 - val_accuracy: 0.5954 - val_loss: 1.5462 - learning_rate: 1.0000e-04
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5576 - loss: 1.6156
# Epoch 42: val_accuracy improved from 0.59542 to 0.60305, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5582 - loss: 1.6129 - val_accuracy: 0.6031 - val_loss: 1.5293 - learning_rate: 1.0000e-04
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5877 - loss: 1.4109
# Epoch 43: val_accuracy improved from 0.60305 to 0.61069, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.5868 - loss: 1.4122 - val_accuracy: 0.6107 - val_loss: 1.5065 - learning_rate: 1.0000e-04
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5748 - loss: 1.4858
# Epoch 44: val_accuracy did not improve from 0.61069
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.5745 - loss: 1.4864 - val_accuracy: 0.6107 - val_loss: 1.4864 - learning_rate: 1.0000e-04
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6073 - loss: 1.4065
# Epoch 45: val_accuracy did not improve from 0.61069
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.6061 - loss: 1.4094 - val_accuracy: 0.6031 - val_loss: 1.4786 - learning_rate: 1.0000e-04
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6334 - loss: 1.4457
# Epoch 46: val_accuracy improved from 0.61069 to 0.62595, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.6319 - loss: 1.4462 - val_accuracy: 0.6260 - val_loss: 1.4577 - learning_rate: 1.0000e-04
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6172 - loss: 1.3437
# Epoch 47: val_accuracy did not improve from 0.62595
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.6179 - loss: 1.3435 - val_accuracy: 0.6260 - val_loss: 1.4442 - learning_rate: 1.0000e-04
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6267 - loss: 1.4520
# Epoch 48: val_accuracy improved from 0.62595 to 0.64122, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.6273 - loss: 1.4479 - val_accuracy: 0.6412 - val_loss: 1.4295 - learning_rate: 1.0000e-04
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6479 - loss: 1.3143
# Epoch 49: val_accuracy did not improve from 0.64122
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.6467 - loss: 1.3168 - val_accuracy: 0.6412 - val_loss: 1.4085 - learning_rate: 1.0000e-04
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6080 - loss: 1.2987
# Epoch 50: val_accuracy did not improve from 0.64122
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.6083 - loss: 1.2999 - val_accuracy: 0.6336 - val_loss: 1.3975 - learning_rate: 1.0000e-04
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6202 - loss: 1.3710
# Epoch 51: val_accuracy did not improve from 0.64122
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.6221 - loss: 1.3691 - val_accuracy: 0.6336 - val_loss: 1.3843 - learning_rate: 1.0000e-04
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6675 - loss: 1.2537
# Epoch 52: val_accuracy did not improve from 0.64122
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.6677 - loss: 1.2527 - val_accuracy: 0.6336 - val_loss: 1.3657 - learning_rate: 1.0000e-04
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7015 - loss: 1.2168
# Epoch 53: val_accuracy improved from 0.64122 to 0.65649, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.6988 - loss: 1.2207 - val_accuracy: 0.6565 - val_loss: 1.3630 - learning_rate: 1.0000e-04
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6014 - loss: 1.3792
# Epoch 54: val_accuracy did not improve from 0.65649
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.6021 - loss: 1.3766 - val_accuracy: 0.6489 - val_loss: 1.3693 - learning_rate: 1.0000e-04
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5951 - loss: 1.4553
# Epoch 55: val_accuracy improved from 0.65649 to 0.66412, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5977 - loss: 1.4470 - val_accuracy: 0.6641 - val_loss: 1.3563 - learning_rate: 1.0000e-04
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6283 - loss: 1.2777
# Epoch 56: val_accuracy did not improve from 0.66412
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.6276 - loss: 1.2794 - val_accuracy: 0.6641 - val_loss: 1.3513 - learning_rate: 1.0000e-04
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6164 - loss: 1.3844
# Epoch 57: val_accuracy did not improve from 0.66412
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.6176 - loss: 1.3787 - val_accuracy: 0.6412 - val_loss: 1.3515 - learning_rate: 1.0000e-04
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6668 - loss: 1.1784
# Epoch 58: val_accuracy did not improve from 0.66412
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.6654 - loss: 1.1812 - val_accuracy: 0.6412 - val_loss: 1.3474 - learning_rate: 1.0000e-04
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6336 - loss: 1.3138
# Epoch 59: val_accuracy did not improve from 0.66412
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.6346 - loss: 1.3088 - val_accuracy: 0.6565 - val_loss: 1.3339 - learning_rate: 1.0000e-04
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6995 - loss: 1.1144
# Epoch 60: val_accuracy did not improve from 0.66412
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.6996 - loss: 1.1175 - val_accuracy: 0.6641 - val_loss: 1.3222 - learning_rate: 1.0000e-04
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6543 - loss: 1.2589
# Epoch 61: val_accuracy improved from 0.66412 to 0.67176, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.6570 - loss: 1.2515 - val_accuracy: 0.6718 - val_loss: 1.3212 - learning_rate: 1.0000e-04
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6563 - loss: 1.2584
# Epoch 62: val_accuracy improved from 0.67176 to 0.68702, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.6573 - loss: 1.2567 - val_accuracy: 0.6870 - val_loss: 1.2983 - learning_rate: 1.0000e-04
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6677 - loss: 1.2296
# Epoch 63: val_accuracy improved from 0.68702 to 0.70992, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.6674 - loss: 1.2292 - val_accuracy: 0.7099 - val_loss: 1.2811 - learning_rate: 1.0000e-04
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6791 - loss: 1.1079
# Epoch 64: val_accuracy improved from 0.70992 to 0.72519, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.6797 - loss: 1.1064 - val_accuracy: 0.7252 - val_loss: 1.2638 - learning_rate: 1.0000e-04
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7287 - loss: 1.0349
# Epoch 65: val_accuracy improved from 0.72519 to 0.73282, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.7284 - loss: 1.0389 - val_accuracy: 0.7328 - val_loss: 1.2474 - learning_rate: 1.0000e-04
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6576 - loss: 1.1572
# Epoch 66: val_accuracy did not improve from 0.73282
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 54s 4s/step - accuracy: 0.6577 - loss: 1.1564 - val_accuracy: 0.7252 - val_loss: 1.2304 - learning_rate: 1.0000e-04
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6709 - loss: 1.1804
# Epoch 67: val_accuracy did not improve from 0.73282
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.6720 - loss: 1.1787 - val_accuracy: 0.7176 - val_loss: 1.2225 - learning_rate: 1.0000e-04
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6681 - loss: 1.1636
# Epoch 68: val_accuracy did not improve from 0.73282
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.6693 - loss: 1.1608 - val_accuracy: 0.7252 - val_loss: 1.2207 - learning_rate: 1.0000e-04
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7182 - loss: 1.0425
# Epoch 69: val_accuracy improved from 0.73282 to 0.74046, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.7183 - loss: 1.0426 - val_accuracy: 0.7405 - val_loss: 1.2196 - learning_rate: 1.0000e-04
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7238 - loss: 1.0886
# Epoch 70: val_accuracy did not improve from 0.74046
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 58s 4s/step - accuracy: 0.7235 - loss: 1.0882 - val_accuracy: 0.7405 - val_loss: 1.2029 - learning_rate: 1.0000e-04
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6919 - loss: 1.1064
# Epoch 71: val_accuracy improved from 0.74046 to 0.75573, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.6932 - loss: 1.1027 - val_accuracy: 0.7557 - val_loss: 1.1872 - learning_rate: 1.0000e-04
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7405 - loss: 1.0698
# Epoch 72: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.7406 - loss: 1.0674 - val_accuracy: 0.7405 - val_loss: 1.1779 - learning_rate: 1.0000e-04
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6797 - loss: 1.0585
# Epoch 73: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.6807 - loss: 1.0578 - val_accuracy: 0.7405 - val_loss: 1.1610 - learning_rate: 1.0000e-04
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7152 - loss: 1.0260
# Epoch 74: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 60s 4s/step - accuracy: 0.7166 - loss: 1.0237 - val_accuracy: 0.7405 - val_loss: 1.1519 - learning_rate: 1.0000e-04
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7799 - loss: 0.9253
# Epoch 75: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.7773 - loss: 0.9291 - val_accuracy: 0.7405 - val_loss: 1.1469 - learning_rate: 1.0000e-04
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6952 - loss: 1.0828
# Epoch 76: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6958 - loss: 1.0822 - val_accuracy: 0.7328 - val_loss: 1.1412 - learning_rate: 1.0000e-04
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7214 - loss: 0.9962
# Epoch 77: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.7209 - loss: 0.9965 - val_accuracy: 0.7328 - val_loss: 1.1312 - learning_rate: 1.0000e-04
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7752 - loss: 0.9575
# Epoch 78: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.7742 - loss: 0.9604 - val_accuracy: 0.7481 - val_loss: 1.1137 - learning_rate: 1.0000e-04
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7396 - loss: 1.0082
# Epoch 79: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 84s 6s/step - accuracy: 0.7405 - loss: 1.0060 - val_accuracy: 0.7481 - val_loss: 1.1010 - learning_rate: 1.0000e-04
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7361 - loss: 0.9805
# Epoch 80: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 75s 5s/step - accuracy: 0.7359 - loss: 0.9787 - val_accuracy: 0.7481 - val_loss: 1.0972 - learning_rate: 1.0000e-04
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7219 - loss: 1.0393
# Epoch 81: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.7233 - loss: 1.0348 - val_accuracy: 0.7405 - val_loss: 1.0941 - learning_rate: 1.0000e-04
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7322 - loss: 0.9630
# Epoch 82: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.7327 - loss: 0.9625 - val_accuracy: 0.7405 - val_loss: 1.0855 - learning_rate: 1.0000e-04
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7313 - loss: 0.9797
# Epoch 83: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 68s 5s/step - accuracy: 0.7320 - loss: 0.9787 - val_accuracy: 0.7405 - val_loss: 1.0772 - learning_rate: 1.0000e-04
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7585 - loss: 0.9711
# Epoch 84: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - accuracy: 0.7582 - loss: 0.9698 - val_accuracy: 0.7481 - val_loss: 1.0699 - learning_rate: 1.0000e-04
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7733 - loss: 0.9040
# Epoch 85: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 88s 4s/step - accuracy: 0.7721 - loss: 0.9059 - val_accuracy: 0.7405 - val_loss: 1.0673 - learning_rate: 1.0000e-04
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7419 - loss: 0.9283
# Epoch 86: val_accuracy did not improve from 0.75573
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step - accuracy: 0.7413 - loss: 0.9295 - val_accuracy: 0.7557 - val_loss: 1.0592 - learning_rate: 1.0000e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7413 - loss: 0.9077
# Epoch 87: val_accuracy improved from 0.75573 to 0.77863, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 95s 6s/step - accuracy: 0.7419 - loss: 0.9072 - val_accuracy: 0.7786 - val_loss: 1.0526 - learning_rate: 1.0000e-04
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7811 - loss: 0.9092
# Epoch 88: val_accuracy did not improve from 0.77863
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 109s 7s/step - accuracy: 0.7813 - loss: 0.9094 - val_accuracy: 0.7786 - val_loss: 1.0438 - learning_rate: 1.0000e-04
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7503 - loss: 0.9538
# Epoch 89: val_accuracy did not improve from 0.77863
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 101s 5s/step - accuracy: 0.7513 - loss: 0.9508 - val_accuracy: 0.7634 - val_loss: 1.0379 - learning_rate: 1.0000e-04
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7576 - loss: 0.9007
# Epoch 90: val_accuracy did not improve from 0.77863
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.7575 - loss: 0.9024 - val_accuracy: 0.7786 - val_loss: 1.0239 - learning_rate: 1.0000e-04
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7499 - loss: 0.9065
# Epoch 91: val_accuracy improved from 0.77863 to 0.78626, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.7513 - loss: 0.9029 - val_accuracy: 0.7863 - val_loss: 1.0213 - learning_rate: 1.0000e-04
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7582 - loss: 0.9580
# Epoch 92: val_accuracy did not improve from 0.78626
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - accuracy: 0.7584 - loss: 0.9548 - val_accuracy: 0.7863 - val_loss: 1.0240 - learning_rate: 1.0000e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7653 - loss: 0.9086
# Epoch 93: val_accuracy did not improve from 0.78626
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - accuracy: 0.7661 - loss: 0.9070 - val_accuracy: 0.7634 - val_loss: 1.0266 - learning_rate: 1.0000e-04
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7645 - loss: 0.9130
# Epoch 94: val_accuracy improved from 0.78626 to 0.80153, saving model to best_model.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 110s 6s/step - accuracy: 0.7645 - loss: 0.9118 - val_accuracy: 0.8015 - val_loss: 1.0225 - learning_rate: 1.0000e-04
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8056 - loss: 0.8133
# Epoch 95: val_accuracy did not improve from 0.80153
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.8055 - loss: 0.8124 - val_accuracy: 0.7939 - val_loss: 1.0172 - learning_rate: 1.0000e-04
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7839 - loss: 0.8043
# Epoch 96: val_accuracy did not improve from 0.80153
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.7840 - loss: 0.8050 - val_accuracy: 0.7939 - val_loss: 1.0105 - learning_rate: 1.0000e-04
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7804 - loss: 0.8518
# Epoch 97: val_accuracy did not improve from 0.80153
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - accuracy: 0.7807 - loss: 0.8525 - val_accuracy: 0.7939 - val_loss: 1.0153 - learning_rate: 1.0000e-04
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7699 - loss: 0.8950
# Epoch 98: val_accuracy did not improve from 0.80153
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 75s 4s/step - accuracy: 0.7697 - loss: 0.8929 - val_accuracy: 0.7710 - val_loss: 1.0161 - learning_rate: 1.0000e-04
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7766 - loss: 0.8083
# Epoch 99: val_accuracy did not improve from 0.80153
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 61s 4s/step - accuracy: 0.7761 - loss: 0.8103 - val_accuracy: 0.7710 - val_loss: 1.0108 - learning_rate: 1.0000e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7901 - loss: 0.8477
# Epoch 100: val_accuracy did not improve from 0.80153
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.7893 - loss: 0.8480 - val_accuracy: 0.7710 - val_loss: 1.0069 - learning_rate: 1.0000e-04

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("ggplot")
plt.figure(figsize=(14, 5))
 
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Cari nilai maksimum dan epoch-nya
max_train_acc = max(train_acc)
epoch_max_train = train_acc.index(max_train_acc)

max_val_acc = max(val_acc)
epoch_max_val = val_acc.index(max_val_acc)

# Cari loss terendah (optional)
min_train_loss = min(train_loss)
epoch_min_train_loss = train_loss.index(min_train_loss)

min_val_loss = min(val_loss)
epoch_min_val_loss = val_loss.index(min_val_loss)

# --- Plot Akurasi ---
plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Train Accuracy', color='blue', linewidth=2)
plt.plot(val_acc, label='Validation Accuracy', color='green', linewidth=2)
plt.title('Training vs Validation Accuracy', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.grid(True)
plt.legend()

# Anotasi train accuracy tertinggi
plt.annotate(f"{max_train_acc*100:.2f}%", 
             xy=(epoch_max_train, max_train_acc), 
             xytext=(epoch_max_train+2, max_train_acc-0.05),
             arrowprops=dict(arrowstyle="->", color='blue'),
             color='blue', fontsize=10)

# Anotasi val accuracy tertinggi
plt.annotate(f"{max_val_acc*100:.2f}%", 
             xy=(epoch_max_val, max_val_acc), 
             xytext=(epoch_max_val+2, max_val_acc+0.05),
             arrowprops=dict(arrowstyle="->", color='green'),
             color='green', fontsize=10)

# --- Plot Loss ---
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Train Loss', color='red', linewidth=2)
plt.plot(val_loss, label='Validation Loss', color='orange', linewidth=2)
plt.title('Training vs Validation Loss', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.grid(True)
plt.legend()

# Anotasi loss terendah (optional)
plt.annotate(f"{min_train_loss:.4f}", 
             xy=(epoch_min_train_loss, min_train_loss), 
             xytext=(epoch_min_train_loss+2, min_train_loss+0.2),
             arrowprops=dict(arrowstyle="->", color='red'),
             color='red', fontsize=10)

plt.annotate(f"{min_val_loss:.4f}", 
             xy=(epoch_min_val_loss, min_val_loss), 
             xytext=(epoch_min_val_loss+2, min_val_loss+0.2),
             arrowprops=dict(arrowstyle="->", color='orange'),
             color='orange', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Evaluasi model di data validasi
loss, acc = model.evaluate(validGenerator, verbose=1)

# Ambil akurasi terbaik selama training
train_acc_max = max(history.history['accuracy'])
val_acc_max = max(history.history['val_accuracy'])

# Cetak hasil
print("\n📊 Evaluasi Model")
print("=" * 40)
print(f"🔹 Akurasi Train Tertinggi  : {train_acc_max * 100:.2f}%")
print(f"🔹 Akurasi Valid Tertinggi  : {val_acc_max * 100:.2f}%")
print(f"🔹 Akurasi Valid Terakhir   : {acc * 100:.2f}%")
print(f"🔹 Loss Valid Terakhir      : {loss:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7887 - loss: 1.0010
#
# 📊 Evaluasi Model
# ========================================
# 🔹 Akurasi Train Tertinggi  : 80.33%
# 🔹 Akurasi Valid Tertinggi  : 80.15%
# 🔹 Akurasi Valid Terakhir   : 77.10%
# 🔹 Loss Valid Terakhir      : 1.0069

# %%
import os
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Path folder test
test_root = "D:/dataset_daun/test"

# Ambil label kelas dari train generator (pastikan 'trainGenerator' sudah tersedia sebelumnya)
class_labels = list(trainGenerator.class_indices.keys())

# Untuk menyimpan hasil prediksi
predictions = []

print("📦 Memulai prediksi gambar di folder test...\n")

# Loop setiap folder kelas
for class_dir in sorted(os.listdir(test_root)):
    class_path = os.path.join(test_root, class_dir)
    if not os.path.isdir(class_path):
        continue

    # Loop setiap gambar dalam folder kelas
    for fname in sorted(os.listdir(class_path)):
        if not fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            continue

        img_path = os.path.join(class_path, fname)

        # Preprocessing gambar (mengikuti preprocessing MobileNetV3)
        img = image.load_img(img_path, target_size=(320, 320))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)  # <- penting: pakai ini sesuai training

        # Prediksi gambar
        pred = model.predict(img_array, verbose=0)
        predicted_class = np.argmax(pred)
        confidence = np.max(pred)

        # Simpan hasil
        true_label = class_dir
        predicted_label = class_labels[predicted_class]
        predictions.append((fname, true_label, predicted_label, confidence))

        # Tampilkan hasil prediksi
        print(f"📷 {fname}")
        print(f"   ✅ Ground Truth : {true_label}")
        print(f"   🧠 Prediksi     : {predicted_label} ({confidence * 100:.2f}%)\n")

# Hitung akurasi prediksi di folder test
correct = sum(1 for p in predictions if p[1] == p[2])
total = len(predictions)

if total > 0:
    accuracy = 100 * correct / total
    print(f"\n✅ Akurasi di folder test: {correct}/{total} = {accuracy:.2f}%")
else:
    print("⚠️ Tidak ada gambar yang diproses di folder test.")
# Out:
# 📦 Memulai prediksi gambar di folder test...
#
# 📷 1.JPG
#    ✅ Ground Truth : Amicabilis
#    🧠 Prediksi     : Towutiensis (17.83%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Amicabilis
#    🧠 Prediksi     : Vittelinoides (30.38%)
#
# 📷 8.JPG
#    ✅ Ground Truth : Amicabilis
#    🧠 Prediksi     : Amicabilis (90.74%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Anulata
#    🧠 Prediksi     : Anulata (73.43%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Anulata
#    🧠 Prediksi     : Anulata (55.36%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Anulata
#    🧠 Prediksi     : Anulata (94.61%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Australis (56.38%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Australis (88.59%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Polypus (35.19%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Australis (83.67%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (53.38%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (98.74%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (98.70%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (64.50%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (55.10%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (63.87%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (98.52%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (97.43%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Garut 1
#    🧠 Prediksi     : Garut 1 (50.50%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Garut 1
#    🧠 Prediksi     : campanulata white (49.67%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Garut 1 (79.04%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Gunung Lawu Lumajang (52.62%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Gunung Lawu Lumajang (42.10%)
#
# 📷 6.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Gunung Lawu Lumajang (36.87%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Hypolasia
#    🧠 Prediksi     : Hypolasia (99.84%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Hypolasia
#    🧠 Prediksi     : Hypolasia (97.65%)
#
# 📷 7.JPG
#    ✅ Ground Truth : Hypolasia
#    🧠 Prediksi     : Hypolasia (88.90%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Incurvula
#    🧠 Prediksi     : Incurvula (36.18%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Incurvula
#    🧠 Prediksi     : Obovata (43.67%)
#
# 📷 5.JPG
#    ✅ Ground Truth : Incurvula
#    🧠 Prediksi     : Dolichosparte (65.33%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Mamasa (54.45%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Mamasa (84.85%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Mamasa (25.88%)
#
# 📷 30.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Mamasa (63.29%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (92.37%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (78.48%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (61.78%)
#
# 📷 5.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (84.86%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Monetteae (50.27%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Monetteae (75.33%)
#
# 📷 23.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Monetteae (52.18%)
#
# 📷 25.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Unchinata (12.21%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (97.91%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (97.66%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (99.45%)
#
# 📷 6.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (99.75%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Polypus
#    🧠 Prediksi     : Obovata (51.11%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Polypus
#    🧠 Prediksi     : Polypus (49.01%)
#
# 📷 5.JPG
#    ✅ Ground Truth : Polypus
#    🧠 Prediksi     : Polypus (88.73%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Polypus kalteng
#    🧠 Prediksi     : Polypus kalteng (56.13%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Polypus kalteng
#    🧠 Prediksi     : Garut 1 (27.86%)
#
# 📷 8.JPG
#    ✅ Ground Truth : Polypus kalteng
#    🧠 Prediksi     : Polypus kalteng (44.24%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Rigidifolia
#    🧠 Prediksi     : Rigidifolia (90.23%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Rigidifolia
#    🧠 Prediksi     : Rigidifolia (18.64%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Rigidifolia
#    🧠 Prediksi     : Rigidifolia (96.75%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Surisana
#    🧠 Prediksi     : Surisana (84.91%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Surisana
#    🧠 Prediksi     : Surisana (63.46%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Surisana
#    🧠 Prediksi     : Surisana (43.82%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Garut 1 (38.08%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (83.58%)
#
# 📷 23.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (33.18%)
#
# 📷 25.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (64.31%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (91.47%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Mamasa (11.99%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Unchinata (71.78%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Unchinata (49.50%)
#
# 📷 30.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Unchinata (97.41%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Vitellina
#    🧠 Prediksi     : Vitellina (70.92%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Vitellina
#    🧠 Prediksi     : Vitellina (75.11%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Vitellina
#    🧠 Prediksi     : Vitellina (97.88%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (96.53%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (86.74%)
#
# 📷 25.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (93.33%)
#
# 📷 6.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (99.87%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (99.25%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Walicii ssp Tenebrosa
#    🧠 Prediksi     : Walicii ssp Tenebrosa (84.93%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Walicii ssp Tenebrosa
#    🧠 Prediksi     : campanulata white (40.64%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Walicii ssp Tenebrosa
#    🧠 Prediksi     : Walicii ssp Tenebrosa (71.82%)
#
# 📷 10.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : campanulata white (97.30%)
#
# 📷 16.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : campanulata white (81.92%)
#
# 📷 23.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : Garut 1 (81.49%)
#
# 📷 25.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : campanulata white (55.14%)
#
# 📷 1.JPG
#    ✅ Ground Truth : caudata
#    🧠 Prediksi     : caudata (91.14%)
#
# 📷 12.JPG
#    ✅ Ground Truth : caudata
#    🧠 Prediksi     : caudata (88.96%)
#
# 📷 5.JPG
#    ✅ Ground Truth : caudata
#    🧠 Prediksi     : caudata (96.13%)
#
# 📷 1.JPG
#    ✅ Ground Truth : occultata silver
#    🧠 Prediksi     : occultata silver (76.34%)
#
# 📷 12.JPG
#    ✅ Ground Truth : occultata silver
#    🧠 Prediksi     : Surisana (22.22%)
#
# 📷 9.JPG
#    ✅ Ground Truth : occultata silver
#    🧠 Prediksi     : occultata silver (35.36%)
#
# 📷 10.JPG
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (90.29%)
#
# 📷 16.JPG
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (99.45%)
#
# 📷 23.JPG
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (99.03%)
#
# 📷 25.jpg
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (94.36%)
#
#
# ✅ Akurasi di folder test: 77/92 = 83.70%

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Prediksi semua batch validasi
Y_pred = model.predict(validGenerator, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)
y_true = validGenerator.classes
labels = list(validGenerator.class_indices.keys())

# Validasi jumlah label
if len(np.unique(y_true)) != len(labels):
    print(f"⚠️ Jumlah kelas y_true = {len(np.unique(y_true))}, tapi jumlah label di generator = {len(labels)}")
    print("Pastikan semua kelas ada minimal 1 gambar di folder validasi.")
else:
    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(14, 12))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels, cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

    # Classification Report
    print("📋 Classification Report:")
    print(classification_report(y_true, y_pred, target_names=labels))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step
# 📋 Classification Report:
#                        precision    recall  f1-score   support
#
#            Amicabilis       1.00      0.50      0.67         4
#               Anulata       0.57      1.00      0.73         4
#             Australis       1.00      0.80      0.89         5
#        Callistophylla       0.67      0.80      0.73         5
#         Dolichosparte       0.83      1.00      0.91         5
#               Garut 1       0.30      0.75      0.43         4
#  Gunung Lawu Lumajang       0.60      0.75      0.67         4
#             Hypolasia       1.00      1.00      1.00         4
#             Incurvula       1.00      0.60      0.75         5
#                Mamasa       0.83      0.83      0.83         6
#            Minahassae       0.80      0.80      0.80         5
#             Monetteae       1.00      0.86      0.92         7
#               Obovata       1.00      1.00      1.00         4
#               Polypus       1.00      0.60      0.75         5
#       Polypus kalteng       1.00      0.50      0.67         4
#           Rigidifolia       1.00      0.75      0.86         4
#              Surisana       0.80      1.00      0.89         4
#           Towutiensis       1.00      0.75      0.86         8
#             Unchinata       0.62      0.83      0.71         6
#             Vitellina       0.60      0.60      0.60         5
#         Vittelinoides       1.00      1.00      1.00         6
# Walicii ssp Tenebrosa       0.33      0.50      0.40         4
#     campanulata white       0.71      0.71      0.71         7
#               caudata       1.00      0.60      0.75         5
#      occultata silver       0.75      0.75      0.75         4
#             waymaniae       1.00      0.71      0.83         7
#
#              accuracy                           0.77       131
#             macro avg       0.82      0.77      0.77       131
#          weighted avg       0.84      0.77      0.78       131

# %%
import tensorflow as tf

# Konversi langsung dari model terlatih di memori
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Simpan ke file .tflite
with open("model/mobilenetv2_daun.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ Model langsung disimpan sebagai TFLite: mobilenetv2_daun.tflite")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ASUS\AppData\Local\Temp\tmpm0doj1r8\assets
# INFO:tensorflow:Assets written to: C:\Users\ASUS\AppData\Local\Temp\tmpm0doj1r8\assets
# Saved artifact at 'C:\Users\ASUS\AppData\Local\Temp\tmpm0doj1r8'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 320, 320, 3), dtype=tf.float32, name='keras_tensor_326')
# Output Type:
#   TensorSpec(shape=(None, 26), dtype=tf.float32, name=None)
# Captures:
#   2814917644304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917643248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917647120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917642016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917644656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917653280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917651696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917655040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917650464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917653104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917575952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917578240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917581232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917577008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917579648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917652400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917584576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917587744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917583344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917585984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917585280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917479408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917482752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917478176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917480816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917489088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917487504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917490672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917486272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917488912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917492432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917330896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917333536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917329664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917332128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917339696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917338112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917341456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917336880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917339520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917344976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917625280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917627920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917624576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917626512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917338816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917633024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917636192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917631616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917634432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917633728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917118608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917121424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917117376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917119136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917127760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917126176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917129344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917124944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917127584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917131104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917020832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917018368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917020656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917019952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917027520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917025936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917029280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917024704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917027344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917032448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917004096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917003568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917003744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917003216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917026640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917009552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917012720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917008320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917010960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917015712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916856464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916855760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916855584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916854704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814917015536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916861744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916864912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916860512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916863152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916868256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916839904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916839376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916838496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916839024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916848176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916846592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916845360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916848000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916853104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915364464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915367104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915363056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915365696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814916847296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915370448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915373616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915369216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915371856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915376608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914954864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915375904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914954512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915376432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914960496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914963664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914959264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914961904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914967008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915610400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915610048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914968592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915609872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915617088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915615504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915618848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915614272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915616912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915622016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915593664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915623600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915624128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915592432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915616208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915599120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915602288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915597888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915600528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915605280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915605632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915606864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915607392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915314784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915605104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915320240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915323408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915319008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915321648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915329392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915327456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915329040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915329216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915298224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915328336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915303504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915306848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915302272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915304912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915313184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915301744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915309488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915312480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915133504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915304208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915138080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915141248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915139488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915147408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915145824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915149168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915144592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915147232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915144064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914875584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914878752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914874352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914876992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814915146528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914883680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914886848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914882448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914885088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914884384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914809696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914813040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914808464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914811104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914819376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914817792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914820960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914816560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914819200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914810400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914744160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914747328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914742928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914745568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914755072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914753488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914753312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914752256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914754896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914751728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914696240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914699408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914695008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914697648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914704336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914702752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914705920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914701520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914704160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2814914703456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990325408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990328752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990324176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990326816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990335088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990333504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990336672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990332272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990334912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990326112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989997728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990000896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989996496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989999136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990007056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990005472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990008816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990004240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990006880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990003712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989604160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989607328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989602928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989605568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990006176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989612256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989615424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989611024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989613664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989612960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989522416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989525232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989521184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989522944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989531568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989529984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989533152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989528752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989531392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989535088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990045296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990047936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990043888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990046528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990055856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990056736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989586368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989584960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813990058672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989585664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989590416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989591120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989593936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989596400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989593584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989595168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989600800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2813989596224: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Model langsung disimpan sebagai TFLite: mobilenetv2_daun.tflite

# %% [markdown]
# # Untuk cek folder test

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# === Path ke model TFLite ===
tflite_model_path = "C:/Users/ASUS/Documents/Python/BRIN/MobileNetV2/model/mobilenetv2_daun.tflite"  # Ubah ke model bunga jika perlu

# === Load interpreter TFLite ===
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(f"✅ Model TFLite dimuat: {tflite_model_path}\n")

# === Path folder test ===
test_root = "D:/dataset_daun/test"

# Ambil label kelas dari trainGenerator
class_labels = list(trainGenerator.class_indices.keys())

predictions = []

print("📦 Mulai prediksi gambar di folder test...\n")

# Loop folder kelas
for class_dir in sorted(os.listdir(test_root)):
    class_path = os.path.join(test_root, class_dir)
    if not os.path.isdir(class_path):
        continue

    for fname in sorted(os.listdir(class_path)):
        if not fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            continue

        img_path = os.path.join(class_path, fname)

        # Preprocessing gambar
        img = image.load_img(img_path, target_size=(320, 320))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array.astype(np.float32))  # Sesuaikan dtype

        # Inferensi TFLite
        interpreter.set_tensor(input_details[0]['index'], img_array)
        interpreter.invoke()
        pred = interpreter.get_tensor(output_details[0]['index'])

        predicted_class = np.argmax(pred)
        confidence = np.max(pred)

        true_label = class_dir
        predicted_label = class_labels[predicted_class]
        predictions.append((fname, true_label, predicted_label, confidence))

        print(f"📷 {fname}")
        print(f"   ✅ Ground Truth : {true_label}")
        print(f"   🧠 Prediksi     : {predicted_label} ({confidence * 100:.2f}%)\n")

# === Hitung Akurasi Test ===
correct = sum(1 for p in predictions if p[1] == p[2])
total = len(predictions)

if total > 0:
    accuracy = 100 * correct / total
    print(f"\n✅ Akurasi di folder test: {correct}/{total} = {accuracy:.2f}%")
else:
    print("⚠️ Tidak ada gambar yang diproses di folder test.")
# Out:
# c:\Users\ASUS\Documents\Python\BRIN\MobileNetV3\envi_V3\lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# ✅ Model TFLite dimuat: C:/Users/ASUS/Documents/Python/BRIN/MobileNetV2/model/mobilenetv2_daun.tflite
#
# 📦 Mulai prediksi gambar di folder test...
#
# 📷 1.JPG
#    ✅ Ground Truth : Amicabilis
#    🧠 Prediksi     : Amicabilis (25.99%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Amicabilis
#    🧠 Prediksi     : Amicabilis (18.70%)
#
# 📷 8.JPG
#    ✅ Ground Truth : Amicabilis
#    🧠 Prediksi     : Amicabilis (70.88%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Anulata
#    🧠 Prediksi     : Mamasa (29.75%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Anulata
#    🧠 Prediksi     : Towutiensis (30.79%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Anulata
#    🧠 Prediksi     : Minahassae (39.76%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Australis (60.47%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Australis (98.18%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Towutiensis (55.98%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Australis
#    🧠 Prediksi     : Australis (63.08%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (39.41%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (98.74%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (99.23%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Callistophylla
#    🧠 Prediksi     : Callistophylla (65.34%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (56.50%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (78.25%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (94.07%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Dolichosparte
#    🧠 Prediksi     : Dolichosparte (88.85%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Garut 1
#    🧠 Prediksi     : Garut 1 (34.88%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Garut 1
#    🧠 Prediksi     : campanulata white (56.02%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Garut 1 (70.23%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Unchinata (35.45%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Gunung Lawu Lumajang (63.28%)
#
# 📷 6.JPG
#    ✅ Ground Truth : Gunung Lawu Lumajang
#    🧠 Prediksi     : Unchinata (43.09%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Hypolasia
#    🧠 Prediksi     : Hypolasia (96.34%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Hypolasia
#    🧠 Prediksi     : Hypolasia (96.94%)
#
# 📷 7.JPG
#    ✅ Ground Truth : Hypolasia
#    🧠 Prediksi     : Hypolasia (95.42%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Incurvula
#    🧠 Prediksi     : Incurvula (42.82%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Incurvula
#    🧠 Prediksi     : Incurvula (52.23%)
#
# 📷 5.JPG
#    ✅ Ground Truth : Incurvula
#    🧠 Prediksi     : Dolichosparte (63.17%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Mamasa (34.30%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Mamasa (68.25%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Minahassae (29.10%)
#
# 📷 30.JPG
#    ✅ Ground Truth : Mamasa
#    🧠 Prediksi     : Mamasa (54.78%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (66.13%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (80.24%)
#
# 📷 28.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (68.86%)
#
# 📷 5.JPG
#    ✅ Ground Truth : Minahassae
#    🧠 Prediksi     : Minahassae (86.27%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Surisana (23.78%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Monetteae (80.20%)
#
# 📷 23.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Monetteae (48.79%)
#
# 📷 25.JPG
#    ✅ Ground Truth : Monetteae
#    🧠 Prediksi     : Amicabilis (19.74%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (99.03%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (95.56%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (98.05%)
#
# 📷 6.JPG
#    ✅ Ground Truth : Obovata
#    🧠 Prediksi     : Obovata (99.49%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Polypus
#    🧠 Prediksi     : Polypus (43.04%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Polypus
#    🧠 Prediksi     : Polypus (34.84%)
#
# 📷 5.JPG
#    ✅ Ground Truth : Polypus
#    🧠 Prediksi     : Polypus (62.22%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Polypus kalteng
#    🧠 Prediksi     : Polypus kalteng (57.98%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Polypus kalteng
#    🧠 Prediksi     : Polypus kalteng (37.09%)
#
# 📷 8.JPG
#    ✅ Ground Truth : Polypus kalteng
#    🧠 Prediksi     : Polypus kalteng (57.10%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Rigidifolia
#    🧠 Prediksi     : Rigidifolia (88.50%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Rigidifolia
#    🧠 Prediksi     : campanulata white (34.50%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Rigidifolia
#    🧠 Prediksi     : Rigidifolia (85.11%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Surisana
#    🧠 Prediksi     : Surisana (77.78%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Surisana
#    🧠 Prediksi     : Surisana (37.68%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Surisana
#    🧠 Prediksi     : Unchinata (28.82%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Polypus (37.00%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (57.03%)
#
# 📷 23.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (19.47%)
#
# 📷 25.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (60.27%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Towutiensis
#    🧠 Prediksi     : Towutiensis (80.87%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Unchinata (21.93%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Unchinata (89.64%)
#
# 📷 17.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Unchinata (52.02%)
#
# 📷 30.JPG
#    ✅ Ground Truth : Unchinata
#    🧠 Prediksi     : Unchinata (94.11%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Vitellina
#    🧠 Prediksi     : Dolichosparte (34.39%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Vitellina
#    🧠 Prediksi     : Vitellina (61.51%)
#
# 📷 4.JPG
#    ✅ Ground Truth : Vitellina
#    🧠 Prediksi     : Vitellina (94.58%)
#
# 📷 10.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (95.57%)
#
# 📷 16.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (50.44%)
#
# 📷 25.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (84.47%)
#
# 📷 6.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (99.61%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Vittelinoides
#    🧠 Prediksi     : Vittelinoides (97.77%)
#
# 📷 1.JPG
#    ✅ Ground Truth : Walicii ssp Tenebrosa
#    🧠 Prediksi     : Walicii ssp Tenebrosa (67.53%)
#
# 📷 12.JPG
#    ✅ Ground Truth : Walicii ssp Tenebrosa
#    🧠 Prediksi     : campanulata white (52.65%)
#
# 📷 9.JPG
#    ✅ Ground Truth : Walicii ssp Tenebrosa
#    🧠 Prediksi     : Walicii ssp Tenebrosa (58.16%)
#
# 📷 10.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : campanulata white (92.36%)
#
# 📷 16.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : campanulata white (69.18%)
#
# 📷 23.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : Garut 1 (64.41%)
#
# 📷 25.JPG
#    ✅ Ground Truth : campanulata white
#    🧠 Prediksi     : campanulata white (42.77%)
#
# 📷 1.JPG
#    ✅ Ground Truth : caudata
#    🧠 Prediksi     : caudata (70.98%)
#
# 📷 12.JPG
#    ✅ Ground Truth : caudata
#    🧠 Prediksi     : caudata (32.22%)
#
# 📷 5.JPG
#    ✅ Ground Truth : caudata
#    🧠 Prediksi     : caudata (80.69%)
#
# 📷 1.JPG
#    ✅ Ground Truth : occultata silver
#    🧠 Prediksi     : campanulata white (47.40%)
#
# 📷 12.JPG
#    ✅ Ground Truth : occultata silver
#    🧠 Prediksi     : occultata silver (23.36%)
#
# 📷 9.JPG
#    ✅ Ground Truth : occultata silver
#    🧠 Prediksi     : Amicabilis (18.74%)
#
# 📷 10.JPG
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (82.58%)
#
# 📷 16.JPG
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (98.97%)
#
# 📷 23.JPG
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (78.24%)
#
# 📷 25.jpg
#    ✅ Ground Truth : waymaniae
#    🧠 Prediksi     : waymaniae (96.86%)
#
#
# ✅ Akurasi di folder test: 72/92 = 78.26%
